# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
import re
#Directory from og data
file = "Clean Data.csv"
#Insert og data in a pandas DF
data = pd.read_csv(file)
data
# Out:
#                                          Title Release Date Language  Runtime  \
# 0                                       Avatar   2009-12-10       en    162.0
# 1     Pirates of the Caribbean: At World's End   2007-05-19       en    169.0
# 2                                      Spectre   2015-10-26       en    148.0
# 3                        The Dark Knight Rises   2012-07-16       en    165.0
# 4                                  John Carter   2012-03-07       en    132.0
# ...                                        ...          ...      ...      ...
# 2929                            Blue Valentine   2010-12-27       en    112.0
# 2930            Beyond the Valley of the Dolls   1970-07-17       en    109.0
# 2931                         The Green Inferno   2014-09-04       en    100.0
# 2932                     What Happens in Vegas   2008-05-07       da     99.0
# 2933                     The Birth of a Nation   2016-09-09       en    120.0
#
#          Revenue     Budget      Genre  Year  Month  Day      Profit
# 0     2787965087  237000000     Action  2009     12   10  2550965087
# 1      961000000  300000000  Adventure  2007      5   19   661000000
# 2      880674609  245000000     Action  2015     10   26   635674609
# 3     1084939099  250000000     Action  2012      7   16   834939099
# 4      284139100  260000000     Action  2012      3    7    24139100
# ...          ...        ...        ...   ...    ...  ...         ...
# 2929    16566240    3500000      Drama  2010     12   27     7640272
# 2930    40000000    2090000     Comedy  1970      7   17    19307746
# 2931     6833445    5000000     Action  2014      9    4     7144595
# 2932   170000000   35000000     Comedy  2008      5    7     5000000
# 2933    15861566    8500000      Drama  2016      9    9     5737585
#
# [2934 rows x 11 columns]

# %%
bins = [0,1970,1980,1990,2000,2010,2020]
labels = ["60's","70's","80's","90's","2000's","2010's"]
data["Decade"] = pd.cut(data["Year"],bins,labels=labels)
data
# Out:
#                                          Title Release Date Language  Runtime  \
# 0                                       Avatar   2009-12-10       en    162.0
# 1     Pirates of the Caribbean: At World's End   2007-05-19       en    169.0
# 2                                      Spectre   2015-10-26       en    148.0
# 3                        The Dark Knight Rises   2012-07-16       en    165.0
# 4                                  John Carter   2012-03-07       en    132.0
# ...                                        ...          ...      ...      ...
# 2929                            Blue Valentine   2010-12-27       en    112.0
# 2930            Beyond the Valley of the Dolls   1970-07-17       en    109.0
# 2931                         The Green Inferno   2014-09-04       en    100.0
# 2932                     What Happens in Vegas   2008-05-07       da     99.0
# 2933                     The Birth of a Nation   2016-09-09       en    120.0
#
#          Revenue     Budget      Genre  Year  Month  Day      Profit  Decade
# 0     2787965087  237000000     Action  2009     12   10  2550965087  2000's
# 1      961000000  300000000  Adventure  2007      5   19   661000000  2000's
# 2      880674609  245000000     Action  2015     10   26   635674609  2010's
# 3     1084939099  250000000     Action  2012      7   16   834939099  2010's
# 4      284139100  260000000     Action  2012      3    7    24139100  2010's
# ...          ...        ...        ...   ...    ...  ...         ...     ...
# 2929    16566240    3500000      Drama  2010     12   27     7640272  2000's
# 2930    40000000    2090000     Comedy  1970      7   17    19307746    60's
# 2931     6833445    5000000     Action  2014      9    4     7144595  2010's
# 2932   170000000   35000000     Comedy  2008      5    7     5000000  2000's
# 2933    15861566    8500000      Drama  2016      9    9     5737585  2010's
#
# [2934 rows x 12 columns]

# %%
data_group = data.groupby("Genre")
data_size = (data_group["Decade"].count())
data_size
# Out:
# Genre
# Action         569
# Adventure      270
# Animation       95
# Comedy         585
# Crime          128
# Documentary     16
# Drama          631
# Family          38
# Fantasy         88
# History         15
# Horror         174
# Music           16
# Mystery         25
# No Genre         1
# Romance         65
# Science         75
# Thriller       111
# War             15
# Western         17
# Name: Decade, dtype: int64

# %%
count_totals = data["Decade"].value_counts()
count_totals
# Out:
# 2000's    1288
# 2010's     732
# 90's       581
# 80's       202
# 70's        74
# 60's        57
# Name: Decade, dtype: int64

# %%
#Creating dataframe for decades for further ploting
decades=data.groupby(data.Decade)
year1=decades.get_group("60's")
year2=decades.get_group("70's")
year3=decades.get_group("80's")
year4=decades.get_group("90's")
year5=decades.get_group("2000's")
year6=decades.get_group("2010's")

# %%
#60s decade dataframe
year1.head()
# Out:
#                   Title Release Date Language  Runtime   Revenue    Budget  \
# 813              Lolita   1962-06-13       en    153.0   9250000   2000000
# 1045          Cleopatra   1963-06-12       en    248.0  71000000  31115000
# 1658  Tora! Tora! Tora!   1970-01-26       en    144.0  29548291  25485000
# 1711           Waterloo   1970-10-26       en    128.0   3052000  25000000
# 1858   Paint Your Wagon   1969-10-15       en    158.0  31678778  20000000
#
#         Genre  Year  Month  Day     Profit Decade
# 813     Drama  1962      6   13    7250000   60's
# 1045    Drama  1963      6   12  115674180   60's
# 1658  History  1970      1   26   25671850   60's
# 1711  History  1970     10   26   46009334   60's
# 1858    Drama  1969     10   15   58378744   60's

# %%
#70s dataframe
year2.head()
# Out:
#                               Title Release Date Language  Runtime    Revenue  \
# 770                        Superman   1978-12-13       en    143.0  300218018
# 821                     Superman II   1980-12-04       en    127.0  190458706
# 1030                  Heaven's Gate   1980-11-19       en    219.0    3484331
# 1246  Star Trek: The Motion Picture   1979-12-06       en    132.0  139000000
# 1277             The Bad News Bears   1976-04-07       en    102.0   35323292
#
#         Budget    Genre  Year  Month  Day     Profit Decade
# 770   55000000   Action  1978     12   13  245218018   70's
# 821   54000000   Action  1980     12    4  136458706   70's
# 1030  44000000   Action  1980     11   19   81700000   70's
# 1246  35000000  Science  1979     12    6  291551094   70's
# 1277  35000000   Comedy  1976      4    7   24901913   70's

# %%
#80s dataframe
year3.head()
# Out:
#                    Title Release Date Language  Runtime    Revenue    Budget  \
# 205         Total Recall   1990-06-01       en    113.0  261317921  65000000
# 372  Conan the Barbarian   1982-04-02       en    129.0   79114085  20000000
# 408            Creepshow   1982-11-12       en    120.0   21028755   8000000
# 552           Die Hard 2   1990-07-02       en    124.0  240031094  70000000
# 565            The Abyss   1989-08-09       en    139.0   90000098  70000000
#
#          Genre  Year  Month  Day     Profit Decade
# 205     Action  1990      6    1  196317921   80's
# 372  Adventure  1982      4    2   59114085   80's
# 408     Horror  1982     11   12   13028755   80's
# 552     Action  1990      7    2  170031094   80's
# 565  Adventure  1989      8    9   20000098   80's

# %%
#90s dataframe
year4.head()
# Out:
#                Title Release Date Language  Runtime     Revenue     Budget  \
# 25           Titanic   1997-11-18       en    194.0  1845034188  200000000
# 70    Wild Wild West   1999-06-29       en    106.0   222104681  170000000
# 75        Waterworld   1995-07-28       en    135.0   264218220  175000000
# 147       Armageddon   1998-07-01       en    151.0   553799566  140000000
# 162  Lethal Weapon 4   1998-07-10       en    127.0   285444603  140000000
#
#          Genre  Year  Month  Day      Profit Decade
# 25       Drama  1997     11   18  1645034188   90's
# 70      Action  1999      6   29    52104681   90's
# 75   Adventure  1995      7   28    89218220   90's
# 147     Action  1998      7    1   413799566   90's
# 162     Action  1998      7   10   145444603   90's

# %%
#2000s dataframe
year5.head()
# Out:
#                                       Title Release Date Language  Runtime  \
# 0                                    Avatar   2009-12-10       en    162.0
# 1  Pirates of the Caribbean: At World's End   2007-05-19       en    169.0
# 5                              Spider-Man 3   2007-05-01       en    139.0
# 6                                   Tangled   2010-11-24       en    100.0
# 8    Harry Potter and the Half-Blood Prince   2009-07-07       en    153.0
#
#       Revenue     Budget      Genre  Year  Month  Day      Profit  Decade
# 0  2787965087  237000000     Action  2009     12   10  2550965087  2000's
# 1   961000000  300000000  Adventure  2007      5   19   661000000  2000's
# 5   890871626  258000000    Fantasy  2007      5    1   632871626  2000's
# 6   591794936  260000000  Animation  2010     11   24   331794936  2000's
# 8   933959197  250000000  Adventure  2009      7    7   683959197  2000's

# %%
#2010s dataframe
year6.head()
# Out:
#                                 Title Release Date Language  Runtime  \
# 2                             Spectre   2015-10-26       en    148.0
# 3               The Dark Knight Rises   2012-07-16       en    165.0
# 4                         John Carter   2012-03-07       en    132.0
# 7             Avengers: Age of Ultron   2015-04-22       en    141.0
# 9  Batman v Superman: Dawn of Justice   2016-03-23       en    151.0
#
#       Revenue     Budget   Genre  Year  Month  Day      Profit  Decade
# 2   880674609  245000000  Action  2015     10   26   635674609  2010's
# 3  1084939099  250000000  Action  2012      7   16   834939099  2010's
# 4   284139100  260000000  Action  2012      3    7    24139100  2010's
# 7  1405403694  280000000  Action  2015      4   22  1125403694  2010's
# 9   873260194  250000000  Action  2016      3   23   623260194  2010's

# %%
#dataframe for analyzing Genre Vs Runtime
df_1 = data.loc[:, ["Title", "Genre", "Runtime"]]
df_1
# Out:
#                                          Title      Genre  Runtime
# 0                                       Avatar     Action    162.0
# 1     Pirates of the Caribbean: At World's End  Adventure    169.0
# 2                                      Spectre     Action    148.0
# 3                        The Dark Knight Rises     Action    165.0
# 4                                  John Carter     Action    132.0
# ...                                        ...        ...      ...
# 2929                            Blue Valentine      Drama    112.0
# 2930            Beyond the Valley of the Dolls     Comedy    109.0
# 2931                         The Green Inferno     Action    100.0
# 2932                     What Happens in Vegas     Comedy     99.0
# 2933                     The Birth of a Nation      Drama    120.0
#
# [2934 rows x 3 columns]

# %%
#dataframe for analyzing genre vs budget
df_2=data.loc[:, ["Title", "Genre", "Budget"]]
df_2
# Out:
#                                          Title      Genre     Budget
# 0                                       Avatar     Action  237000000
# 1     Pirates of the Caribbean: At World's End  Adventure  300000000
# 2                                      Spectre     Action  245000000
# 3                        The Dark Knight Rises     Action  250000000
# 4                                  John Carter     Action  260000000
# ...                                        ...        ...        ...
# 2929                            Blue Valentine      Drama    3500000
# 2930            Beyond the Valley of the Dolls     Comedy    2090000
# 2931                         The Green Inferno     Action    5000000
# 2932                     What Happens in Vegas     Comedy   35000000
# 2933                     The Birth of a Nation      Drama    8500000
#
# [2934 rows x 3 columns]

# %%
#dataframe for analyzing genre vs profit
df_3=data.loc[:,["Title","Genre","Profit"]]
df_3
# Out:
#                                          Title      Genre      Profit
# 0                                       Avatar     Action  2550965087
# 1     Pirates of the Caribbean: At World's End  Adventure   661000000
# 2                                      Spectre     Action   635674609
# 3                        The Dark Knight Rises     Action   834939099
# 4                                  John Carter     Action    24139100
# ...                                        ...        ...         ...
# 2929                            Blue Valentine      Drama     7640272
# 2930            Beyond the Valley of the Dolls     Comedy    19307746
# 2931                         The Green Inferno     Action     7144595
# 2932                     What Happens in Vegas     Comedy     5000000
# 2933                     The Birth of a Nation      Drama     5737585
#
# [2934 rows x 3 columns]
